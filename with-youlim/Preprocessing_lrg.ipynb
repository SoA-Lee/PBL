# %% [markdown]
# # 데이터 분석하기

# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline

# %%
DATA_IN_PATH = './data_in/'
print("파일 크기 : ")
for file in os.listdir(DATA_IN_PATH):
    if 'csv' in file :
        print(file.ljust(30) + str(round(os.path.getsize(DATA_IN_PATH + file) / 1000000, 2)) + 'MB')
# Out:
# 파일 크기 :
# soa.csv                       0.0MB
# testdata.csv                  0.79MB
# testdata_answer.csv           0.8MB
# test_clean.csv                1.09MB
# traindata.csv                 0.73MB
# train_clean.csv               1.0MB

# %% [markdown]
# # 데이터전처리

# %%
# import numpy as np
# import pandas as pd
# import re
# import json
# from konlpy.tag import Okt
# from tensorflow.python.keras.preprocessing.sequence import pad_sequences
# from tensorflow.python.keras.preprocessing.text import Tokenizer

# %%
import warnings
import pandas as pd
warnings.filterwarnings(action='ignore')
DATA_IN_PATH = './data_in/'

# %%
train_data = pd.read_csv(DATA_IN_PATH+'traindata.csv', names=['sentence','label'])
train_data.head()
# Out:
#                                             sentence  label
# 0                                         개같은 소리 하지마      1
# 1                                          좌배 까는건 ㅇㅂ      1
# 2        개소리야 니가 빨갱이를 옹호하고 드루킹을 ㅇㅇ짓이라고 말못해서 삐진거야 빨갱아      1
# 3                                  애새끼가 초딩도 아니고 ㅋㅋㅋㅋ      1
# 4  731부대의 후예라 그런지 가학적인 아이디어는 세계최고임 이래서 애교만 떨어도 돈 ...      1

# %%
print('전체 학습데이터의 개수: {}'.format(len(train_data)))
# Out:
# 전체 학습데이터의 개수: 8245

# %%
train_length = train_data['sentence'].astype(str).apply(len)
train_length.head()
# Out:
# 0     10
# 1      9
# 2     43
# 3     17
# 4    106
# Name: sentence, dtype: int64

# %%
# 그래프에 대한 이미지 사이즈 선언
# figsize: (가로, 세로) 형태의 튜플로 입력
plt.figure(figsize=(12, 5))
# 히스토그램 선언
# bins: 히스토그램 값들에 대한 버켓 범위
# range: x축 값의 범위
# alpha: 그래프 색상 투명도
# color: 그래프 색상
# label: 그래프에 대한 라벨
plt.hist(train_length, bins=200, alpha=0.5, color= 'r', label='word')
plt.yscale('log', nonposy='clip')
# 그래프 제목
plt.title('Log-Histogram of length of Sentence')
# 그래프 x 축 라벨
plt.xlabel('Length of Sentence')
# 그래프 y 축 라벨
plt.ylabel('Number of Sentence')
# Out:
# Text(0, 0.5, 'Number of Sentence')

# %%
print('문장 길이 최대 값: {}'.format(np.max(train_length)))
print('문장 길이 최소 값: {}'.format(np.min(train_length)))
print('문장 길이 평균 값: {:.2f}'.format(np.mean(train_length)))
print('문장 길이 표준편차: {:.2f}'.format(np.std(train_length)))
print('문장 길이 중간 값: {}'.format(np.median(train_length)))
# 사분위의 대한 경우는 0~100 스케일로 되어있음
print('문장 길이 제 1 사분위: {}'.format(np.percentile(train_length, 25)))
print('문장 길이 제 3 사분위: {}'.format(np.percentile(train_length, 75)))
# Out:
# 문장 길이 최대 값: 1000
# 문장 길이 최소 값: 1
# 문장 길이 평균 값: 33.88
# 문장 길이 표준편차: 36.63
# 문장 길이 중간 값: 28.0
# 문장 길이 제 1 사분위: 19.0
# 문장 길이 제 3 사분위: 39.0

# %%
plt.figure(figsize=(12, 5))
# 박스플롯 생성
# 첫번째 파라메터: 여러 분포에 대한 데이터 리스트를 입력
# labels: 입력한 데이터에 대한 라벨
# showmeans: 평균값을 마크함

plt.boxplot(train_length,
             labels=['counts'],
             showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21989cd8790>,
#   <matplotlib.lines.Line2D at 0x21989cd87c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x21989cd83a0>,
#   <matplotlib.lines.Line2D at 0x21989cd1f40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21989cd8a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x21989cd10a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21989c34970>],
#  'means': [<matplotlib.lines.Line2D at 0x21989cd1a30>]}

# %%
fig, axe = plt.subplots(ncols=1)
fig.set_size_inches(6, 3)
sns.countplot(train_data['label'])

# %%
print("긍정 리뷰 개수: {}".format(train_data['label'].value_counts()[0]))
print("부정 리뷰 개수: {}".format(train_data['label'].value_counts()[1]))
# Out:
# 긍정 리뷰 개수: 4123
# 부정 리뷰 개수: 4122

# %% [markdown]
# # 데이터 전처리_책version

# %%
import numpy as np
import pandas as pd
import re
import json
from konlpy.tag import Okt
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer

# %%
train_data = pd.read_csv(DATA_IN_PATH+'traindata.csv', names=['sentence','label'])
train_data.head()
# Out:
#                                             sentence  label
# 0                                         개같은 소리 하지마      1
# 1                                          좌배 까는건 ㅇㅂ      1
# 2        개소리야 니가 빨갱이를 옹호하고 드루킹을 ㅇㅇ짓이라고 말못해서 삐진거야 빨갱아      1
# 3                                  애새끼가 초딩도 아니고 ㅋㅋㅋㅋ      1
# 4  731부대의 후예라 그런지 가학적인 아이디어는 세계최고임 이래서 애교만 떨어도 돈 ...      1

# %%
sentence_text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", train_data['sentence'][2]) 
print(sentence_text)
# Out:
# 개소리야 니가 빨갱이를 옹호하고 드루킹을 ㅇㅇ짓이라고 말못해서 삐진거야 빨갱아

# %%
okt=Okt()
sentence_text = okt.morphs(sentence_text, stem=True)
print(sentence_text)
# Out:
# ['개', '소리', '야', '니', '가', '빨갱이', '를', '옹호', '하고', '드루', '킹', '을', 'ㅇㅇ', '짓', '이라고', '말', '못', '하다', '삐지다', '빨갱', '아']

# %%
stop_words = set(['은', '는', '이', '가', '하', '아', '것', '들','의', '있', '되', '수', '보', '주', '등', '한'])
clean_sentence = [token for token in sentence_text if not token in stop_words]
print(clean_sentence)
# Out:
# ['개', '소리', '야', '니', '빨갱이', '를', '옹호', '하고', '드루', '킹', '을', 'ㅇㅇ', '짓', '이라고', '말', '못', '하다', '삐지다', '빨갱']

# %%
def preprocessing(sentence, okt, remove_stopwords = False, stop_words = []):
    # 함수의 인자는 다음과 같다.
    # sentence : 전처리할 텍스트
    # okt : okt 객체를 반복적으로 생성하지 않고 미리 생성후 인자로 받는다.
    # remove_stopword : 불용어를 제거할지 선택 기본값은 False
    # stop_word : 불용어 사전은 사용자가 직접 입력해야함 기본값은 비어있는 리스트
    
    # 1. 한글 및 공백을 제외한 문자 모두 제거.
    sentence_text = re.sub("[ㄱ-ㅎㅏ-ㅣ\\s]+", "", sentence) 
    
    
    # 2. okt 객체를 활용해서 형태소 단위로 나눈다.
    wd_sentence = okt.morphs(sentence_text, stem=True)
    
    if remove_stopwords:
        
        # 불용어 제거(선택적)
        wd_sentence = [token for token in wd_sentence if not token in stop_words]
        
   
    return wd_sentence

# %%
stop_words = [ '은', '는', '이', '가', '하', '아', '것', '들','의', '있', '되', '수', '보', '주', '등', '한']
okt = Okt()
clean_train_sentence = []

for review in train_data['sentence']:
    # 비어있는 데이터에서 멈추지 않도록 string인 경우만 진행
    if type(review) == str:
        clean_train_sentence.append(preprocessing(review, okt, remove_stopwords = True, stop_words=stop_words))
    else:
        clean_train_sentence.append([])  #string이 아니면 비어있는 값 추가
clean_train_sentence[:4]

clean_train_df = pd.DataFrame({'sentence':clean_train_sentence,'label':train_data['label']})

# %%
test_data = pd.read_csv(DATA_IN_PATH + 'testdata.csv', names=['sentence','label'] )
#test_data = pd.read_csv(DATA_IN_PATH + 'testdata.csv', names=['sentence'] )

clean_test_sentence = []

for review in test_data['sentence']:
    # 비어있는 데이터에서 멈추지 않도록 string인 경우만 진행
    if type(review) == str:
        clean_test_sentence.append(preprocessing(review, okt, remove_stopwords = True, stop_words=stop_words))
    else:
        clean_test_sentence.append([])  #string이 아니면 비어있는 값 추가
        
clean_test_df = pd.DataFrame({'sentence':clean_test_sentence,'label':test_data['label']})
#clean_test_df = pd.DataFrame({'sentence':clean_test_sentence})

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(clean_train_sentence)
tokenizer.fit_on_texts(clean_test_sentence) # 새로 추가함
train_sequences = tokenizer.texts_to_sequences(clean_train_sentence)
test_sequences = tokenizer.texts_to_sequences(clean_test_sentence)

word_vocab = tokenizer.word_index # 단어 사전 형태
# word_vocab["<PAD>"] = 0

# %%
MAX_SEQUENCE_LENGTH = 36 # 문장 최대 길이, 중간값 지정

train_inputs = pad_sequences(train_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post') # 학습 데이터를 벡터화
train_labels = np.array(train_data['label']) # 학습 데이터의 라벨

test_inputs = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post') # 테스트 데이터를 벡터화
test_labels = np.array(test_data['label']) # 평가 데이터의 라벨

# %%
DATA_IN_PATH = './data_in/'
TRAIN_INPUT_DATA = 'train_input.npy'
TRAIN_LABEL_DATA = 'train_label.npy'
TRAIN_CLEAN_DATA = 'train_clean.csv'
TEST_INPUT_DATA = 'nsmc_test_input.npy'
TEST_CLEAN_DATA = 'test_clean.csv'
TEST_LABEL_DATA = 'nsmc_test_label.npy'
DATA_CONFIGS = 'data_configs.json'

data_configs = {}

data_configs['vocab'] = word_vocab
data_configs['vocab_size'] = len(word_vocab) # vocab size 추가

import os
# 저장하는 디렉토리가 존재하지 않으면 생성
if not os.path.exists(DATA_IN_PATH):
    os.makedirs(DATA_IN_PATH)

# 전처리 된 학습 데이터를 넘파이 형태로 저장
np.save(open(DATA_IN_PATH + TRAIN_INPUT_DATA, 'wb'), train_inputs)
np.save(open(DATA_IN_PATH + TRAIN_LABEL_DATA, 'wb'), train_labels)
# 전처리 된 학습 데이터를 csv 형태로 저장
clean_train_df.to_csv(DATA_IN_PATH +TRAIN_CLEAN_DATA, index = False)
clean_test_df.to_csv(DATA_IN_PATH +TEST_CLEAN_DATA, index = False)
# 전처리 된 테스트 데이터를 넘파이 형태로 저장
np.save(open(DATA_IN_PATH + TEST_INPUT_DATA, 'wb'), test_inputs)
np.save(open(DATA_IN_PATH + TEST_LABEL_DATA, 'wb'), test_labels)

# 데이터 사전을 json 형태로 저장
json.dump(data_configs, open(DATA_IN_PATH + DATA_CONFIGS, 'w',encoding='UTF-8'), ensure_ascii=False)

# %% [markdown]
# # 데이터 분할

# %%
X = df['Sentence']
Y = df['Label']

# %% [markdown]
# 1. 백터화
# TFIDF
# CountVectorizer 줄여서 CV

# %%
from sklearn.feature_extraction.text import CountVectorizer

vec_cv = CountVectorizer(analyzer = "word", max_features = 6000) 

X_cv = vec_cv.fit_transform(X)

# %%
X_cv.shape
# Out:
# (5825, 6000)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vec_tf = TfidfVectorizer(min_df = 0.0, analyzer = 'char', sublinear_tf=True, 
    ngram_range = (1,3), max_features=6000)


X_tf = vec_tf.fit_transform(X)

# %%
X_tf.shape
# Out:
# (5825, 6000)

# %%
vec_tf.get_feature_names()
# Out:
# [' ',
#  ' "',
#  " '",
#  ' (',
#  ' ,',
#  ' , ',
#  ' -',
#  ' .',
#  ' . ',
#  ' ..',
#  ' 1',
#  ' 10',
#  ' 15',
#  ' 16',
#  ' 17',
#  ' 18',
#  ' 19',
#  ' 1년',
#  ' 1위',
#  ' 2',
#  ' 20',
#  ' 3',
#  ' 30',
#  ' 4',
#  ' 40',
#  ' 5',
#  ' 50',
#  ' 6',
#  ' 7',
#  ' 7등',
#  ' 8',
#  ' 9',
#  ' :',
#  ' : ',
#  ' =',
#  ' = ',
#  ' ?',
#  ' ? ',
#  ' ^',
#  ' a',
#  ' c',
#  ' d',
#  ' f',
#  ' i',
#  ' k',
#  ' n',
#  ' p',
#  ' s',
#  ' t',
#  ' v',
#  ' w',
#  ' ~',
#  ' ㄱ',
#  ' ㄷ',
#  ' ㄷㄷ',
#  ' ㄹ',
#  ' ㄹㅇ',
#  ' ㅁ',
#  ' ㅁㅈ',
#  ' ㅂ',
#  ' ㅂㄷ',
#  ' ㅂㅅ',
#  ' ㅅ',
#  ' ㅅㄱ',
#  ' ㅅㅂ',
#  ' ㅅㅌ',
#  ' ㅆ',
#  ' ㅆㅅ',
#  ' ㅇ',
#  ' ㅇㅂ',
#  ' ㅇㅇ',
#  ' ㅇㅈ',
#  ' ㅈ',
#  ' ㅈㄴ',
#  ' ㅉ',
#  ' ㅉㅉ',
#  ' ㅋ',
#  ' ㅋ ',
#  ' ㅋㅋ',
#  ' ㅎ',
#  ' ㅎㅎ',
#  ' ㅠ',
#  ' ㅠㅠ',
#  ' ㅡ',
#  ' ㅡㅡ',
#  ' 가',
#  ' 가 ',
#  ' 가격',
#  ' 가끔',
#  ' 가는',
#  ' 가능',
#  ' 가르',
#  ' 가서',
#  ' 가입',
#  ' 가장',
#  ' 가져',
#  ' 가족',
#  ' 가지',
#  ' 가치',
#  ' 각',
#  ' 간',
#  ' 간다',
#  ' 갈',
#  ' 감',
#  ' 갑',
#  ' 갔',
#  ' 강',
#  ' 강간',
#  ' 강사',
#  ' 갖',
#  ' 갖고',
#  ' 같',
#  ' 같다',
#  ' 같은',
#  ' 같음',
#  ' 같이',
#  ' 개',
#  ' 개 ',
#  ' 개꿀',
#  ' 개돼',
#  ' 개병',
#  ' 개새',
#  ' 개소',
#  ' 개씹',
#  ' 개인',
#  ' 개좆',
#  ' 걍',
#  ' 걍 ',
#  ' 걔',
#  ' 거',
#  ' 거 ',
#  ' 거기',
#  ' 거리',
#  ' 거야',
#  ' 거의',
#  ' 거임',
#  ' 거지',
#  ' 걱',
#  ' 걱정',
#  ' 건',
#  ' 건 ',
#  ' 걸',
#  ' 걸레',
#  ' 검',
#  ' 검사',
#  ' 것',
#  ' 것 ',
#  ' 것도',
#  ' 것은',
#  ' 것이',
#  ' 게',
#  ' 게 ',
#  ' 게이',
#  ' 결',
#  ' 결국',
#  ' 결혼',
#  ' 경',
#  ' 경기',
#  ' 경우',
#  ' 경찰',
#  ' 계',
#  ' 계속',
#  ' 고',
#  ' 고기',
#  ' 고백',
#  ' 고소',
#  ' 골',
#  ' 곱',
#  ' 곳',
#  ' 공',
#  ' 공무',
#  ' 공부',
#  ' 공장',
#  ' 과',
#  ' 과거',
#  ' 관',
#  ' 관리',
#  ' 관심',
#  ' 광',
#  ' 광고',
#  ' 괜',
#  ' 괜찮',
#  ' 괴',
#  ' 교',
#  ' 교수',
#  ' 구',
#  ' 구라',
#  ' 구분',
#  ' 국',
#  ' 국가',
#  ' 국룰',
#  ' 국민',
#  ' 군',
#  ' 궁',
#  ' 권',
#  ' 귀',
#  ' 귀천',
#  ' 규',
#  ' 그',
#  ' 그 ',
#  ' 그거',
#  ' 그건',
#  ' 그걸',
#  ' 그것',
#  ' 그게',
#  ' 그냥',
#  ' 그대',
#  ' 그때',
#  ' 그래',
#  ' 그랬',
#  ' 그러',
#  ' 그런',
#  ' 그럴',
#  ' 그럼',
#  ' 그렇',
#  ' 그리',
#  ' 극',
#  ' 근',
#  ' 근거',
#  ' 근데',
#  ' 글',
#  ' 금',
#  ' 급',
#  ' 기',
#  ' 기능',
#  ' 기다',
#  ' 기본',
#  ' 기분',
#  ' 기사',
#  ' 기술',
#  ' 길',
#  ' 김',
#  ' 김씨',
#  ' 김치',
#  ' 까',
#  ' 까지',
#  ' 깔',
#  ' 깜',
#  ' 깨',
#  ' 꺼',
#  ' 꼬',
#  ' 꼭',
#  ' 꼭 ',
#  ' 꼴',
#  ' 꾸',
#  ' 꿀',
#  ' 꿈',
#  ' 끌',
#  ' 끝',
#  ' 끼',
#  ' 나',
#  ' 나 ',
#  ' 나가',
#  ' 나는',
#  ' 나도',
#  ' 나라',
#  ' 나보',
#  ' 나오',
#  ' 나온',
#  ' 나와',
#  ' 나왔',
#  ' 나이',
#  ' 나중',
#  ' 난',
#  ' 난 ',
#  ' 날',
#  ' 날 ',
#  ' 남',
#  ' 남자',
#  ' 낫',
#  ' 낮',
#  ' 내',
#  ' 내 ',
#  ' 내가',
#  ' 내려',
#  ' 내용',
#  ' 너',
#  ' 너 ',
#  ' 너무',
#  ' 넌',
#  ' 넌 ',
#  ' 넘',
#  ' 넘어',
#  ' 넣',
#  ' 네',
#  ' 년',
#  ' 노',
#  ' 노가',
#  ' 노력',
#  ' 노무',
#  ' 노비',
#  ' 노예',
#  ' 노인',
#  ' 논',
#  ' 논리',
#  ' 놀',
#  ' 놈',
#  ' 놈들',
#  ' 놈이',
#  ' 농',
#  ' 높',
#  ' 높은',
#  ' 뇌',
#  ' 누',
#  ' 누가',
#  ' 누구',
#  ' 눈',
#  ' 뉴',
#  ' 뉴스',
#  ' 느',
#  ' 느껴',
#  ' 느낌',
#  ' 늘',
#  ' 능',
#  ' 니',
#  ' 니 ',
#  ' 니가',
#  ' 니들',
#  ' 다',
#  ' 다 ',
#  ' 다니',
#  ' 다들',
#  ' 다르',
#  ' 다른',
#  ' 다시',
#  ' 다음',
#  ' 단',
#  ' 단순',
#  ' 달',
#  ' 닭',
#  ' 담',
#  ' 담배',
#  ' 답',
#  ' 답이',
#  ' 당',
#  ' 당연',
#  ' 당하',
#  ' 대',
#  ' 대가',
#  ' 대구',
#  ' 대기',
#  ' 대단',
#  ' 대부',
#  ' 대체',
#  ' 대통',
#  ' 대학',
#  ' 대한',
#  ' 대해',
#  ' 댓',
#  ' 댓글',
#  ' 더',
#  ' 더 ',
#  ' 덜',
#  ' 데',
#  ' 도',
#  ' 독',
#  ' 돈',
#  ' 돈 ',
#  ' 돈이',
#  ' 돌',
#  ' 돌아',
#  ' 동',
#  ' 동네',
#  ' 돼',
#  ' 됐',
#  ' 되',
#  ' 되는',
#  ' 되면',
#  ' 되어',
#  ' 되지',
#  ' 된',
#  ' 된다',
#  ' 될',
#  ' 될 ',
#  ' 됨',
#  ' 두',
#  ' 둘',
#  ' 둘이',
#  ' 뒤',
#  ' 뒤지',
#  ' 뒤질',
#  ' 뒷',
#  ' 드',
#  ' 드라',
#  ' 듣',
#  ' 들',
#  ' 들고',
#  ' 들어',
#  ' 들었',
#  ' 듯',
#  ' 등',
#  ' 등등',
#  ' 디',
#  ' 따',
#  ' 따라',
#  ' 따지',
#  ' 딱',
#  ' 딱 ',
#  ' 딴',
#  ' 딸',
#  ' 때',
#  ' 때 ',
#  ' 때문',
#  ' 땡',
#  ' 떠',
#  ' 떡',
#  ' 떨',
#  ' 떨어',
#  ' 또',
#  ' 또 ',
#  ' 똑',
#  ' 똑같',
#  ' 똥',
#  ' 뛰',
#  ' 뛰어',
#  ' 뜻',
#  ' 라',
#  ' 라고',
#  ' 라는',
#  ' 레',
#  ' 리',
#  ' 링',
#  ' 링크',
#  ' 마',
#  ' 마음',
#  ' 마찬',
#  ' 막',
#  ' 만',
#  ' 만나',
#  ' 만든',
#  ' 만들',
#  ' 많',
#  ' 많아',
#  ' 많으',
#  ' 많은',
#  ' 많이',
#  ' 말',
#  ' 말 ',
#  ' 말고',
#  ' 말이',
#  ' 말하',
#  ' 맘',
#  ' 맛',
#  ' 망',
#  ' 맞',
#  ' 맞는',
#  ' 맞다',
#  ' 맞음',
#  ' 맞지',
#  ' 맞춰',
#  ' 매',
#  ' 매일',
#  ' 맨',
#  ' 머',
#  ' 머리',
#  ' 먹',
#  ' 먹고',
#  ' 먹는',
#  ' 먼',
#  ' 먼저',
#  ' 멀',
#  ' 멋',
#  ' 멍',
#  ' 멍청',
#  ' 메',
#  ' 면',
#  ' 명',
#  ' 몇',
#  ' 모',
#  ' 모두',
#  ' 모든',
#  ' 모르',
#  ' 목',
#  ' 몰',
#  ' 몰라',
#  ' 몰려',
#  ' 몸',
#  ' 못',
#  ' 못 ',
#  ' 못하',
#  ' 못한',
#  ' 못함',
#  ' 못해',
#  ' 무',
#  ' 무슨',
#  ' 무시',
#  ' 무식',
#  ' 무조',
#  ' 문',
#  ' 문재',
#  ' 문제',
#  ' 물',
#  ' 물론',
#  ' 물어',
#  ' 뭐',
#  ' 뭐 ',
#  ' 뭐가',
#  ' 뭐냐',
#  ' 뭐라',
#  ' 뭐하',
#  ' 뭔',
#  ' 뭔 ',
#  ' 뭔가',
#  ' 뭘',
#  ' 뭘 ',
#  ' 미',
#  ' 미개',
#  ' 미국',
#  ' 미친',
#  ' 민',
#  ' 민주',
#  ' 믿',
#  ' 밀',
#  ' 밑',
#  ' 바',
#  ' 바꿔',
#  ' 바로',
#  ' 박',
#  ' 박정',
#  ' 밖',
#  ' 밖에',
#  ' 반',
#  ' 반대',
#  ' 받',
#  ' 받는',
#  ' 받아',
#  ' 받았',
#  ' 발',
#  ' 발언',
#  ' 발전',
#  ' 밟',
#  ' 밤',
#  ' 밥',
#  ' 방',
#  ' 방송',
#  ' 배',
#  ' 배달',
#  ' 배우',
#  ' 배워',
#  ' 백',
#  ' 버',
#  ' 버는',
#  ' 번',
#  ' 벌',
#  ' 벌어',
#  ' 범',
#  ' 범죄',
#  ' 법',
#  ' 베',
#  ' 베트',
#  ' 변',
#  ' 별',
#  ' 별로',
#  ' 병',
#  ' 병신',
#  ' 병원',
#  ' 보',
#  ' 보고',
#  ' 보내',
#  ' 보는',
#  ' 보니',
#  ' 보다',
#  ' 보면',
#  ' 보수',
#  ' 보여',
#  ' 보이',
#  ' 보지',
#  ' 복',
#  ' 복싱',
#  ' 본',
#  ' 본인',
#  ' 볼',
#  ' 봄',
#  ' 봐',
#  ' 봐도',
#  ' 봤',
#  ' 부',
#  ' 부모',
#  ' 부분',
#  ' 북',
#  ' 북한',
#  ' 분',
#  ' 분탕',
#  ' 불',
#  ' 붙',
#  ' 븅',
#  ' 븅신',
#  ' 브',
#  ' 블',
#  ' 비',
#  ' 비교',
#  ' 비번',
#  ' 비슷',
#  ' 비하',
#  ' 빈',
#  ' 빠',
#  ' 빠는',
#  ' 빡',
#  ' 빡대',
#  ' 빨',
#  ' 빨갱',
#  ' 빨리',
#  ' 빨아',
#  ' 빼',
#  ' 빼고',
#  ' 뽑',
#  ' 뿌',
#  ' 뿐',
#  ' 사',
#  ' 사건',
#  ' 사고',
#  ' 사기',
#  ' 사는',
#  ' 사라',
#  ' 사람',
#  ' 사랑',
#  ' 사실',
#  ' 사용',
#  ' 사이',
#  ' 사장',
#  ' 사진',
#  ' 사회',
#  ' 산',
#  ' 산업',
#  ' 살',
#  ' 살기',
#  ' 살면',
#  ' 살아',
#  ' 삼',
#  ' 상',
#  ' 상관',
#  ' 상대',
#  ' 상황',
#  ' 새',
#  ' 새끼',
#  ' 생',
#  ' 생각',
#  ' 생기',
#  ' 생활',
#  ' 서',
#  ' 서로',
#  ' 서울',
#  ' 선',
#  ' 선거',
#  ' 선생',
#  ' 선진',
#  ' 선택',
#  ' 설',
#  ' 설명',
#  ' 성',
#  ' 성공',
#  ' 세',
#  ' 세계',
#  ' 세금',
#  ' 세상',
#  ' 섹',
#  ' 섹스',
#  ' 센',
#  ' 소',
#  ' 소리',
#  ' 속',
#  ' 손',
#  ' 솔',
#  ' 솔직',
#  ' 송',
#  ' 쇼',
#  ' 수',
#  ' 수 ',
#  ' 수능',
#  ' 수도',
#  ' 수사',
#  ' 수준',
#  ' 수학',
#  ' 순',
#  ' 술',
#  ' 쉬',
#  ' 스',
#  ' 슬',
#  ' 승',
#  ' 시',
#  ' 시간',
#  ' 시대',
#  ' 시발',
#  ' 시작',
#  ' 시장',
#  ' 시절',
#  ' 시켜',
#  ' 시키',
#  ' 식',
#  ' 신',
#  ' 신경',
#  ' 신고',
#  ' 신기',
#  ' 실',
#  ' 실제',
#  ' 싫',
#  ' 싫어',
#  ' 심',
#  ' 싶',
#  ' 싶다',
#  ' 싸',
#  ' 싹',
#  ' 쌍',
#  ' 써',
#  ' 쓰',
#  ' 쓰는',
#  ' 쓰레',
#  ' 쓴',
#  ' 쓸',
#  ' 씨',
#  ' 씨발',
#  ' 씹',
#  ' 씹새',
#  ' 씹창',
#  ' 아',
#  ' 아 ',
#  ' 아가',
#  ' 아는',
#  ' 아니',
#  ' 아닌',
#  ' 아닐',
#  ' 아님',
#  ' 아무',
#  ' 아이',
#  ' 아재',
#  ' 아주',
#  ' 아줌',
#  ' 아직',
#  ' 아파',
#  ' 악',
#  ' 안',
#  ' 안 ',
#  ' 안가',
#  ' 안나',
#  ' 안되',
#  ' 안된',
#  ' 안됨',
#  ' 안먹',
#  ' 안보',
#  ' 안전',
#  ' 안정',
#  ' 안좋',
#  ' 안하',
#  ' 앉',
#  ' 앉아',
#  ' 않',
#  ' 않는',
#  ' 않았',
#  ' 알',
#  ' 알고',
#  ' 알려',
#  ' 알면',
#  ' 알바',
#  ' 알아',
#  ' 알았',
#  ' 암',
#  ' 압',
#  ' 앞',
#  ' 애',
#  ' 애들',
#  ' 애미',
#  ' 야',
#  ' 약',
#  ' 양',
#  ' 양반',
#  ' 얘',
#  ' 얘기',
#  ' 어',
#  ' 어느',
#  ' 어디',
#  ' 어떤',
#  ' 어떻',
#  ' 어렵',
#  ' 어린',
#  ' 어쩌',
#  ' 어차',
#  ' 억',
#  ' 언',
#  ' 언제',
#  ' 얼',
#  ' 얼굴',
#  ' 얼마',
#  ' 엄',
#  ' 엄마',
#  ' 엄청',
#  ' 업',
#  ' 없',
#  ' 없고',
#  ' 없네',
#  ' 없는',
#  ' 없다',
#  ' 없어',
#  ' 없었',
#  ' 없으',
#  ' 없음',
#  ' 없이',
#  ' 없지',
#  ' 에',
#  ' 여',
#  ' 여기',
#  ' 여러',
#  ' 여자',
#  ' 역',
#  ' 역시',
#  ' 연',
#  ' 연락',
#  ' 연예',
#  ' 열',
#  ' 열심',
#  ' 영',
#  ' 영상',
#  ' 영어',
#  ' 영화',
#  ' 옆',
#  ' 옆에',
#  ' 예',
#  ' 예전',
#  ' 오',
#  ' 오래',
#  ' 오지',
#  ' 오히',
#  ' 온',
#  ' 올',
#  ' 올라',
#  ' 올리',
#  ' 옳',
#  ' 옷',
#  ' 와',
#  ' 완',
#  ' 완전',
#  ' 왔',
#  ' 왜',
#  ' 왜 ',
#  ' 외',
#  ' 외국',
#  ' 외모',
#  ' 요',
#  ' 요즘',
#  ' 욕',
#  ' 욕 ',
#  ' 욕하',
#  ' 용',
#  ' 용접',
#  ' 우',
#  ' 우리',
#  ' 우파',
#  ' 운',
#  ' 운동',
#  ' 울',
#  ' 웃',
#  ' 웃기',
#  ' 원',
#  ' 원래',
#  ' 월',
#  ' 월급',
#  ' 위',
#  ' 위장',
#  ' 위해',
#  ' 유',
#  ' 유지',
#  ' 유튜',
#  ' 육',
#  ' 윤',
#  ' 으',
#  ' 은',
#  ' 음',
#  ' 음식',
#  ' 응',
#  ' 의',
#  ' 의료',
#  ' 의미',
#  ' 의사',
#  ' 이',
#  ' 이 ',
#  ' 이거',
#  ' 이건',
#  ' 이걸',
#  ' 이게',
#  ' 이국',
#  ' 이기',
#  ' 이딴',
#  ' 이러',
#  ' 이런',
#  ' 이렇',
#  ' 이름',
#  ' 이미',
#  ' 이번',
#  ' 이쁘',
#  ' 이상',
#  ' 이야',
#  ' 이용',
#  ' 이유',
#  ' 이제',
#  ' 이지',
#  ' 이해',
#  ' 이후',
#  ' 인',
#  ' 인간',
#  ' 인기',
#  ' 인생',
#  ' 인식',
#  ' 인정',
#  ' 인증',
#  ' 인터',
#  ' 일',
#  ' 일 ',
#  ' 일게',
#  ' 일단',
#  ' 일반',
#  ' 일베',
#  ' 일본',
#  ' 일부',
#  ' 일어',
#  ' 일이',
#  ' 일하',
#  ' 일해',
#  ' 읽',
#  ' 임',
#  ' 입',
#  ' 잇',
#  ' 있',
#  ' 있겠',
#  ' 있고',
#  ' 있나',
#  ' 있냐',
#  ' 있네',
#  ' 있는',
#  ' 있다',
#  ' 있어',
#  ' 있었',
#  ' 있으',
#  ' 있을',
#  ' 있음',
#  ' 있지',
#  ' 자',
#  ' 자기',
#  ' 자꾸',
#  ' 자동',
#  ' 자리',
#  ' 자빠',
#  ' 자살',
#  ' 자식',
#  ' 자신',
#  ' 자유',
#  ' 자주',
#  ' 자체',
#  ' 작',
#  ' 잘',
#  ' 잘 ',
#  ' 잘나',
#  ' 잘못',
#  ' 잘하',
#  ' 잘해',
#  ' 잘했',
#  ' 잠',
#  ' 잡',
#  ' 잡아',
#  ' 장',
#  ' 재',
#  ' 재미',
#  ' 재밌',
#  ' 재산',
#  ' 쟤',
#  ' 저',
#  ' 저 ',
#  ' 저거',
#  ' 저게',
#  ' 저기',
#  ' 저능',
#  ' 저러',
#  ' 저런',
#  ' 저렇',
#  ' 저지',
#  ' 적',
#  ' 전',
#  ' 전국',
#  ' 전기',
#  ' 전라',
#  ' 전문',
#  ' 전부',
#  ' 전에',
#  ' 전혀',
#  ' 절',
#  ' 절대',
#  ' 젊',
#  ' 젊은',
#  ' 점',
#  ' 접',
#  ' 정',
#  ' 정당',
#  ' 정도',
#  ' 정말',
#  ' 정보',
#  ' 정부',
#  ' 정상',
#  ' 정설',
#  ' 정신',
#  ' 정치',
#  ' 제',
#  ' 제대',
#  ...]
